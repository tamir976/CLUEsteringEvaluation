# %%
# time elapsed: 2047s

# %%
import random as rnd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs
from math import sqrt
import seaborn as sns
import CLUEstering as clue
import uproot
import awkward as ak
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, MaxAbsScaler, QuantileTransformer
import os
from scipy.stats import zscore
from itertools import product
import plotly.express as px
from collections import Counter
import csv


def scale_x2_by_event_min_max(event_data, event_stats):
    # Use pre-calculated min/max values from event_stats for scaling
    min_x2 = event_stats['x2']['min']
    max_x2 = event_stats['x2']['max']
    
    event_data['x2'] = (event_data['x2'] - min_x2) / (max_x2 - min_x2)
    return event_data

def inverse_scale_x2_by_event_min_max(event_data, event_stats):
    # Use pre-calculated min/max values from event_stats for inverse scaling
    min_x2 = event_stats['x2']['min']
    max_x2 = event_stats['x2']['max']
    
    event_data['x2'] = event_data['x2'] * (max_x2 - min_x2) + min_x2
    return event_data

def normalize_x2_by_event_z_score(event_data, event_stats):
    # Use pre-calculated mean and std from event_stats for z-score normalization
    mean_x2 = event_stats['x2']['mean']
    std_x2 = event_stats['x2']['std']
    
    # Perform Z-score normalization using pre-calculated mean and std
    event_data['x2'] = (event_data['x2'] - mean_x2) / std_x2
    return event_data

def inverse_normalize_x2_by_event_z_score(event_data, event_stats):
    # Use pre-calculated mean and std from event_stats for the inverse z-score
    mean_x2 = event_stats['x2']['mean']
    std_x2 = event_stats['x2']['std']
    
    # Reverse the Z-score normalization using pre-calculated mean and std
    event_data['x2'] = event_data['x2'] * std_x2 + mean_x2
    return event_data
    
def scale_all_features_by_event_min_max(event_data, event_stats): #use
    event_data['x0'] = (event_data['x0'] - event_stats['x0']['min']) / (event_stats['x0']['max'] - event_stats['x0']['min'])
    event_data['x1'] = (event_data['x1'] - event_stats['x1']['min']) / (event_stats['x1']['max'] - event_stats['x1']['min'])
    event_data['x2'] = (event_data['x2'] - event_stats['x2']['min']) / (event_stats['x2']['max'] - event_stats['x2']['min'])
    return event_data

def inverse_scale_all_features_by_event_min_max(event_data, event_stats):
    event_data['x0'] = event_data['x0'] * (event_stats['x0']['max'] - event_stats['x0']['min']) + event_stats['x0']['min']
    event_data['x1'] = event_data['x1'] * (event_stats['x1']['max'] - event_stats['x1']['min']) + event_stats['x1']['min']
    event_data['x2'] = event_data['x2'] * (event_stats['x2']['max'] - event_stats['x2']['min']) + event_stats['x2']['min']
    return event_data

def normalize_all_features_by_event_z_score(event_data, event_stats):
    event_data['x0'] = (event_data['x0'] - event_stats['x0']['mean']) / event_stats['x0']['std']
    event_data['x1'] = (event_data['x1'] - event_stats['x1']['mean']) / event_stats['x1']['std']
    event_data['x2'] = (event_data['x2'] - event_stats['x2']['mean']) / event_stats['x2']['std']
    return event_data

def inverse_normalize_all_features_by_event_z_score(event_data, event_stats):
    event_data['x0'] = event_data['x0'] * event_stats['x0']['std'] + event_stats['x0']['mean']
    event_data['x1'] = event_data['x1'] * event_stats['x1']['std'] + event_stats['x1']['mean']
    event_data['x2'] = event_data['x2'] * event_stats['x2']['std'] + event_stats['x2']['mean']
    return event_data


def scale_x0_x1_min_max_adjust_x2(event_data, event_stats):
    event_data['x0'] = (event_data['x0'] - event_stats['x0']['min']) / (event_stats['x0']['max'] - event_stats['x0']['min'])
    event_data['x1'] = (event_data['x1'] - event_stats['x1']['min']) / (event_stats['x1']['max'] - event_stats['x1']['min'])
    
    adjusted_x2_min = min(event_stats['x2']['min'], event_stats['x0']['min'], event_stats['x1']['min'])
    adjusted_x2_max = max(event_stats['x2']['max'], event_stats['x0']['max'], event_stats['x1']['max'])
    
    event_data['x2'] = (event_data['x2'] - adjusted_x2_min) / (adjusted_x2_max - adjusted_x2_min)
    return event_data

def inverse_scale_x0_x1_min_max_adjust_x2(event_data, event_stats):
    event_data['x0'] = event_data['x0'] * (event_stats['x0']['max'] - event_stats['x0']['min']) + event_stats['x0']['min']
    event_data['x1'] = event_data['x1'] * (event_stats['x1']['max'] - event_stats['x1']['min']) + event_stats['x1']['min']
    
    adjusted_x2_min = min(event_stats['x2']['min'], event_stats['x0']['min'], event_stats['x1']['min'])
    adjusted_x2_max = max(event_stats['x2']['max'], event_stats['x0']['max'], event_stats['x1']['max'])
    
    event_data['x2'] = event_data['x2'] * (adjusted_x2_max - adjusted_x2_min) + adjusted_x2_min
    return event_data

def normalize_x0_x1_z_score_adjust_x2(event_data, event_stats):
    event_data['x0'] = (event_data['x0'] - event_stats['x0']['mean']) / event_stats['x0']['std']
    event_data['x1'] = (event_data['x1'] - event_stats['x1']['mean']) / event_stats['x1']['std']
    
    adjusted_x2_mean = np.mean([event_stats['x2']['mean'], event_stats['x0']['mean'], event_stats['x1']['mean']])
    adjusted_x2_std = np.mean([event_stats['x2']['std'], event_stats['x0']['std'], event_stats['x1']['std']])
    
    event_data['x2'] = (event_data['x2'] - adjusted_x2_mean) / adjusted_x2_std
    return event_data

def inverse_normalize_x0_x1_z_score_adjust_x2(event_data, event_stats):
    adjusted_x2_mean = np.mean([event_stats['x2']['mean'], event_stats['x0']['mean'], event_stats['x1']['mean']])
    adjusted_x2_std = np.mean([event_stats['x2']['std'], event_stats['x0']['std'], event_stats['x1']['std']])
    
    event_data['x0'] = event_data['x0'] * event_stats['x0']['std'] + event_stats['x0']['mean']
    event_data['x1'] = event_data['x1'] * event_stats['x1']['std'] + event_stats['x1']['mean']
    
    event_data['x2'] = event_data['x2'] * adjusted_x2_std + adjusted_x2_mean
    return event_data
    
def scale_x2_by_combined_x0_x1_range(event_data, event_stats):
    min_x01 = (event_stats['x0']['min'] + event_stats['x1']['min']) / 2
    max_x01 = (event_stats['x0']['max'] + event_stats['x1']['max']) / 2

    min_x2, max_x2 = event_stats['x2']['min'], event_stats['x2']['max']
    scale_factor = (max_x01 - min_x01) / (max_x2 - min_x2)
    
    event_data['x2'] = (event_data['x2'] - min_x2) * scale_factor + min_x01
    return event_data

def inverse_scale_x2_by_combined_x0_x1_range(event_data, event_stats):
    min_x01 = (event_stats['x0']['min'] + event_stats['x1']['min']) / 2
    max_x01 = (event_stats['x0']['max'] + event_stats['x1']['max']) / 2

    min_x2, max_x2 = event_stats['x2']['min'], event_stats['x2']['max']
    scale_factor = (max_x2 - min_x2) / (max_x01 - min_x01)
    
    event_data['x2'] = (event_data['x2'] - min_x01) * scale_factor + min_x2
    return event_data



def load_LC_data(root_name):

    file_path = f'rootfiles/{root_name}.root'
    with uproot.open(file_path) as file:
        tree = file["ticlDumper/clusters;1"]
        branches = tree.arrays(['position_x', 'position_y', 'position_z', 'energy'])
        data_points_number = len(branches['position_x'])
    return branches

def get_event_LC_data(event_id, branches):

    x0, x1, x2 = branches['position_x'][event_id], branches['position_y'][event_id], branches['position_z'][event_id]
    weight = branches['energy'][event_id]
    event_data = pd.DataFrame({'x0': x0, 'x1': x1, 'x2': x2, 'weight': weight, 'indices': list(range(len(x0)))})   
    return event_data

def store_stat_values(root_name, event_id, event_data):

    # Store min, max, mean, and std for each feature (x0, x1, x2)
    Original_stat_values[root_name][event_id] = {
        'x0': {
            'min': event_data['x0'].min(),
            'max': event_data['x0'].max(),
            'mean': event_data['x0'].mean(),
            'std': event_data['x0'].std()
        },
        'x1': {
            'min': event_data['x1'].min(),
            'max': event_data['x1'].max(),
            'mean': event_data['x1'].mean(),
            'std': event_data['x1'].std()
        },
        'x2': {
            'min': event_data['x2'].min(),
            'max': event_data['x2'].max(),
            'mean': event_data['x2'].mean(),
            'std': event_data['x2'].std()
        }
    }








def scale_event_data(event_data, scale_method, event_stats):
    # Dictionary of available scaling methods
    scaling_methods = {
        'x2 by event min max': scale_x2_by_event_min_max,
        'x2 by event z-score': normalize_x2_by_event_z_score,
        'all features by event min max': scale_all_features_by_event_min_max,
        'all features by event z-score': normalize_all_features_by_event_z_score,
        'x0 x1 min max adjust x2': scale_x0_x1_min_max_adjust_x2,
        'x0 x1 z-score adjust x2': normalize_x0_x1_z_score_adjust_x2,
        'x2 by combined x0 x1 range': scale_x2_by_combined_x0_x1_range
    }
    
    if scale_method not in scaling_methods:
        raise ValueError(f"Unknown scaling method: {scale_method}")
    
    # Apply the selected scaling method with the relevant event statistics
    return scaling_methods[scale_method](event_data, event_stats)

def inverse_scale_event_data(event_data, scale_method, event_stats):
    # Dictionary of available inverse scaling methods
    inverse_scaling_methods = {
        'x2 by event min max': inverse_scale_x2_by_event_min_max,
        'x2 by event z-score': inverse_normalize_x2_by_event_z_score,
        'all features by event min max': inverse_scale_all_features_by_event_min_max,
        'all features by event z-score': inverse_normalize_all_features_by_event_z_score,
        'x0 x1 min max adjust x2': inverse_scale_x0_x1_min_max_adjust_x2,
        'x0 x1 z-score adjust x2': inverse_normalize_x0_x1_z_score_adjust_x2,
        'x2 by combined x0 x1 range': inverse_scale_x2_by_combined_x0_x1_range
    }
    
    if scale_method not in inverse_scaling_methods:
        raise ValueError(f"No inverse scaling function defined for method: {scale_method}")
    
    # Apply the selected inverse scaling method with the relevant event statistics
    return inverse_scaling_methods[scale_method](event_data, event_stats)


def apply_save_clustering(root_name, event_id, cluestering_input_df, paramset, output_folder):

    clust = clue.clusterer(paramset[0], paramset[1], paramset[2])
    clust.read_data(cluestering_input_df)
    clust.run_clue()
    #clust.cluster_plotter()
    os.makedirs(output_folder, exist_ok=True)
    output_path = root_name + "/CLUESteringResults_" + str(event_id) + ".csv"
    # print(f"\n\nEvent {event_id} successfully clustered and written in {output_path}")
    clust.to_csv('./CLUEsteringOutput/',output_path)
    clustering_output_path = './CLUEsteringOutput/'+output_path
    return clustering_output_path



def save_grid_search_result_max_based(event_reco, dc, rhoc, dm, total_number_LCs, number_clustered_LCs, non_clustered_points_per_config):

    event_data_tracksters = event_reco['tracksters']
    if event_data_tracksters:
        max_energy_trackster = max(event_data_tracksters, key=lambda t: t['total_energy'])
        max_energy_tackster_size = max_energy_trackster['size']
        print(f"Single Particle => Metric Max Energy trackster Size with params {dc, rhoc, dm} is {max_energy_tackster_size}\n")
    else:
        max_energy_tackster_size = 0  # Default to 0 if no tracksters found

    # Append this parameter combination's size to event_parameters
    event_parameters = {
        "dc": dc,
        "rhoc": rhoc,
        "dm": dm,
        "max_energy_trackster_size": max_energy_tackster_size,
        "points_per_config": total_number_LCs,
        "clustered_points_per_config" : number_clustered_LCs,
        "non_clustered_points_per_config": non_clustered_points_per_config,
        "number_of_clusters_per_config" :len(event_data_tracksters)
    }
    return event_parameters

def sim_to_reco_score(sim_indices, reco_indices, event_data, fractionSim):
    numerator_sum, denominator_sum = 0.0, 0.0   
    shared_energy_sim_to_reco = 0.0
    # Loop through each LC in Sim trackster
    for LC, frac_sim in zip(list(sim_indices), fractionSim): 
        
        # Retrieve LC_energy from Raw_data_before_clustering
        lc_energy = next((event_data['weight'][i] for i, raw_idx in enumerate(event_data['indices']) if raw_idx == LC), 0)

        if LC in reco_indices:
            # case of overlapping LC 
            frac_reco = 1                        
        else:
            frac_reco = 0
        
        point_numerator = min((frac_reco - frac_sim) ** 2, frac_sim ** 2) * lc_energy ** 2
        point_denominator = frac_sim ** 2 * lc_energy ** 2
        shared_energy_sim_to_reco += frac_reco*(frac_sim*lc_energy)
        numerator_sum += point_numerator
        denominator_sum += point_denominator                    
                        
    score = numerator_sum / denominator_sum
    
    # Return calculated values
    return round(score, 8), round(shared_energy_sim_to_reco, 8)

def process_sim_trackster_efficiency(sim_trackster, sim_metrics, efficiency_threshold):
    
    reco_ids = [
        i for i in range(len(sim_metrics["sim to reco fraction"]))
        if sim_metrics["sim to reco fraction"][i] > efficiency_threshold
    ]
    
    if reco_ids:  # Efficient if at least one reco trackster meets the threshold
        return True, sim_metrics
    return False, None

def event_sim_to_reco(event_id, event_data, sim_id, sim_trackster, reco_tracksters):
    sim_indices = sim_trackster['layer_cluster_indices']
    sim_energy = sim_trackster['total_energy']
    sim_size = sim_trackster['size']
    # print(f"------------Processing Sim trackster {sim_id}------------") 
    
    # to store list of scores and shared energies of each reco trackster 
    sim_to_reco_scores_list = []   
    sim_to_reco_shared_energy_list = []
    sim_to_reco_shared_energy_fraction_list = []
    
    # print(f"Sim Trackster ID: {sim_id}")
    # print(f"Sim Total Energy: {sim_energy}")
    # print(f"Sim Trackster Size: {sim_size}")

    # Calculate fractionSim based on vertices multiplicity
    vertices_multiplicity = sim_trackster['vertices_multiplicity']
    fractionSim = [1.0 / vm for vm in vertices_multiplicity]    
                  
    for reco_trackster in reco_tracksters:
        reco_id = reco_trackster['trackster_id']
        reco_indices = reco_trackster['layer_cluster_indices']
        reco_energy = reco_trackster['total_energy']
        reco_size = reco_trackster['size']
        # print(f"   ---Processing Sim trackster {sim_id} with Reco trackster {reco_id}---")

        score, shared_energy_sim_to_reco = sim_to_reco_score(sim_indices, reco_indices, event_data, fractionSim)
        
        sim_to_reco_scores_list.append(score)
        sim_to_reco_shared_energy_list. append(shared_energy_sim_to_reco)
        sim_to_reco_shared_energy_fraction_list.append(shared_energy_sim_to_reco/sim_energy)
        # print(f"   Reco Trackster ID: {reco_id}")
        # print(f"   Reco Total Energy: {sim_energy}")
        # print(f"   Reco Trackster Size: {sim_size}")             
        # print(f"   Score:{score}, shared energy:{shared_energy_sim_to_reco}, fraction:{sim_to_reco_shared_energy_fraction_list[-1]}")

    reco_ids = [i for i in range(len(sim_to_reco_scores_list)) if sim_to_reco_scores_list[i] < merge_threshold]
    sim_metrics = {
        "trackster id":sim_id,
        "sim energy":sim_energy,
        "reco ids": reco_ids,
        "scores":sim_to_reco_scores_list,
        "shared energy":sim_to_reco_shared_energy_list,
        "sim to reco fraction":sim_to_reco_shared_energy_fraction_list
    }
    return sim_metrics


def find_merge(sim_to_merged_reco_idx, reco_trackster_number):
            
    flattened_sim_to_merged_reco_idx = [reco_idx for reco_list in sim_to_merged_reco_idx for reco_idx in reco_list]

    # Count occurrences using Counter or make a hashmap
    occurrences_reco_ids = Counter(flattened_sim_to_merged_reco_idx)
   
    # Find Reco IDs that occur in more than one sim trackster
    reco_ids_with_multiple_occurrences = [key for key, val in occurrences_reco_ids.items() if val > 1]    
    # print(f"Reco IDs that occur in more than one sim trackster:", reco_ids_with_multiple_occurrences)       
    
    merge_rate = len(reco_ids_with_multiple_occurrences)/reco_trackster_number
    return merge_rate


def save_grid_search_result_merge_based(event_id, event_data, event_reco, event_sim, dc, rhoc, dm, merge_threshold, efficiency_threshold):
    if event_reco['tracksters']:
        sim_to_merged_reco_idx = []
        efficient_sim_tracksters_list = []
        num_efficient_sim_tracksters = 0
        sim_track_number = event_sim['number_of_tracksters']
        
        # Loop over each sim trackster
        for sim_trackster in event_sim['tracksters']:            
            sim_id = sim_trackster['trackster_id']
            reco_tracksters = event_reco['tracksters']
            reco_trackster_number = event_reco['number_of_tracksters']

            # print(f"\n\nFor {dc, rhoc, dm}:")
            sim_metrics = event_sim_to_reco(event_id, event_data, sim_id, sim_trackster, reco_tracksters)
            sim_to_merged_reco_idx.append(sim_metrics['reco ids'])
            
            #Efficiency:
            is_efficient, efficient_metrics = process_sim_trackster_efficiency(sim_trackster, sim_metrics, efficiency_threshold)
            if is_efficient:
                efficient_sim_tracksters_list.append(efficient_metrics)
                num_efficient_sim_tracksters += 1
                
        merge_rate = find_merge(sim_to_merged_reco_idx, reco_trackster_number)
        efficiency = num_efficient_sim_tracksters/ sim_track_number
        
    else:
        merge_rate = 1
        efficiency = 0

    # Append this parameter combination's size to event_parameters
    event_parameters = {
        "dc": dc,
        "rhoc": rhoc,
        "dm": dm,
        "merge rate": merge_rate, 
        "efficiency": efficiency
    }
    return event_parameters

def CLUEstering_trackster_properties(root_name, event_id, event_data, grouped_data, dc, rhoc, dm, multi_particle, merge_threshold, efficiency_threshold, event_params_metrics):

    CLUEstering_tracksters_list = []
    total_number_LCs, number_clustered_LCs = 0, 0
    non_clustered_points_per_config = 0

    for cluster_id, group in grouped_data:
        total_number_LCs += len(group)
        
        if cluster_id == -1:
            # print(f"  No. of Outliers is {len(group)}")
            continue 

        total_energy = group['weight'].sum()
        barycenter = (
            (group['x0'] * group['weight']).sum() / total_energy,
            (group['x1'] * group['weight']).sum() / total_energy,
            (group['x2'] * group['weight']).sum() / total_energy
        )
        
        size = len(group)
        # print(f"  No. of Clustered LCs in cluster {cluster_id} is {size}")
        
        layer_indices = group['indices'].tolist()
        
        min_x2_idx, max_x2_idx = group['x2'].idxmin(), group['x2'].idxmax()
        CLUEstering_tracksters_list.append({
            "trackster_id": cluster_id,
            "first_layer_cluster": group.loc[min_x2_idx, ['x0', 'x1', 'x2', 'weight', 'indices']].to_dict(),
            "last_layer_cluster": group.loc[max_x2_idx, ['x0', 'x1', 'x2', 'weight', 'indices']].to_dict(),
            "layer_cluster_indices": layer_indices,
            "total_energy": total_energy,
            "size": size,
            "barycenter_x": barycenter[0],
            "barycenter_y": barycenter[1],
            "barycenter_z": barycenter[2]
        })
        # print(f"  Trackster {cluster_id} has energy {total_energy} and size {size}")
        
        number_clustered_LCs += size
        
        
    # print(f'Total LCs in Event {total_number_LCs}')
    # print(f'No. of clustered LCs {number_clustered_LCs}')

    fraction = number_clustered_LCs / total_number_LCs if total_number_LCs > 0 else 0

    CLUEstering_results[root_name][event_id] = {
        "number_of_tracksters": len(CLUEstering_tracksters_list),
        "tracksters": CLUEstering_tracksters_list,
        "fraction": fraction
    }
    # print(f"No. of tracksters: {CLUEstering_results[root_name][event_id]['number_of_tracksters']}")
  
    event_reco = CLUEstering_results[root_name][event_id]
    
    if multi_particle:
        event_sim = sim_results[root_name][event_id]
        event_param_metric = save_grid_search_result_merge_based(event_id, event_data, event_reco, event_sim, dc, rhoc, dm, merge_threshold, efficiency_threshold)
    else:
        event_param_metric = save_grid_search_result_max_based(event_reco, dc, rhoc, dm, total_number_LCs, number_clustered_LCs, non_clustered_points_per_config)
    
    # print("Event parameters: ", event_param_metric, "\n")
    event_params_metrics.append(event_param_metric)
    # print("Event params: " , event_params_metrics)
    
    return event_params_metrics


def store_stat_values(root_name, event_id, event_data):

    # Ensure that Original_stat_values is initialized for the current root_name
    if root_name not in Original_stat_values:
        Original_stat_values[root_name] = {}

    if event_data.empty:
        # print(f"Event {event_id} of {root_name} has no data. Skipping statistics calculation.")
        return  # Skip storing statistics for empty events

    # Store min, max, mean, and std for each feature (x0, x1, x2)
    Original_stat_values[root_name][event_id] = {
        'x0': {
            'min': event_data['x0'].min(),
            'max': event_data['x0'].max(),
            'mean': event_data['x0'].mean(),
            'std': event_data['x0'].std()
        },
        'x1': {
            'min': event_data['x1'].min(),
            'max': event_data['x1'].max(),
            'mean': event_data['x1'].mean(),
            'std': event_data['x1'].std()
        },
        'x2': {
            'min': event_data['x2'].min(),
            'max': event_data['x2'].max(),
            'mean': event_data['x2'].mean(),
            'std': event_data['x2'].std()
        }
    }
    
# Define the cost function outside of find_optimum_with_cost_function
def cost_function(param, w_merge_rate, w_efficiency):
    merge_rate = param['merge rate']
    efficiency = param['efficiency']
    # Penalize merge rate heavily, reward efficiency lightly
    cost = w_merge_rate * merge_rate - w_efficiency * efficiency
    return cost


def find_optimum_with_cost_function():
    # Dictionary to store the best parameter set for each event
    event_best = {}
    # Dictionary to aggregate cost scores for each parameter set across all events
    overall_scores = {}

    # Weights for the cost function
    w_merge_rate = 0.9  # Focus on minimizing merge rate
    w_efficiency = 0.1  # Less weight on efficiency

    for root, events in all_events_grid_data.items():
        for event_id, param_list in events.items():
            # Filter out parameter sets with efficiency below 0.7
            valid_params = [param for param in param_list if param['efficiency'] >= 0.7]
            
            # If no valid parameters exist, skip this event
            if not valid_params:
                continue
            
            # Find the best parameter set for this event based on the cost function
            best_param = min(valid_params, key=lambda param: cost_function(param, w_merge_rate, w_efficiency))
            event_best[event_id] = best_param
            
            # Aggregate cost scores for each parameter set to find the overall best
            for param in valid_params:
                param_tuple = tuple(param.items())
                if param_tuple not in overall_scores:
                    overall_scores[param_tuple] = 0
                overall_scores[param_tuple] += cost_function(param, w_merge_rate, w_efficiency)
    
    # If there are no valid parameters overall, handle it gracefully
    if not overall_scores:
        print("No valid parameters found across all events.")
        return
    
    # Find the parameter set with the lowest total cost across all events
    overall_best_tuple = min(overall_scores, key=overall_scores.get)
    overall_best = dict(overall_best_tuple)
    
    # Save event_best to a CSV file
    with open('event_best_with_cost.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        # Write header
        writer.writerow(['Event', 'dc', 'rhoc', 'dm', 'merge rate', 'efficiency'])
        
        # Write each event's best parameters
        for event_id, params in event_best.items():
            writer.writerow([event_id, params['dc'], params['rhoc'], params['dm'], params['merge rate'], params['efficiency']])
    
    print("Best parameters per event saved to event_best_with_cost.csv")
    print("\nOverall best parameters:", overall_best)

def read_store_tracksters_properties(root_name, event_id, raw_data_df, vertices_indexes, vertices_energy, barycenters, data_type, vertices_multiplicity=None):

    # Declarations    
    tracksters_list = []
    tracksters_energy = {}
    results = {
        root_name: {
            event_id: {}
        }
    }
    
    print(f"Processing {data_type} Event {event_id} in {root_name} with {len(vertices_indexes)} tracksters...")
    for trackster_id, (trackster_indexes, trackster_energies) in enumerate(zip(vertices_indexes, vertices_energy)):

        total_energy = sum(trackster_energies)
        tracksters_energy[trackster_id] = {
            'total_energy': total_energy,
            'vertices_indexes': trackster_indexes
        }
        filtered_data = raw_data_df[raw_data_df['indices'].isin(trackster_indexes)]

        # Find indices of rows with minimum and maximum x2 values
        min_x2_idx = filtered_data['x2'].idxmin()
        max_x2_idx = filtered_data['x2'].idxmax()

        # Retrieve the rows with min and max x2 values
        first_layer = (filtered_data.loc[min_x2_idx, ['x0', 'x1', 'x2', 'weight', 'indices']]).to_dict()
        last_layer = (filtered_data.loc[max_x2_idx, ['x0', 'x1', 'x2', 'weight', 'indices']]).to_dict()

        trackster_info = {
            'trackster_id': trackster_id,
            'total_energy': total_energy,
            'layer_cluster_indices': trackster_indexes.tolist(),
            'size': len(trackster_indexes),
            'first_layer_cluster': first_layer,
            'last_layer_cluster': last_layer,
            'barycenter_x': barycenters[0][trackster_id],
            'barycenter_y': barycenters[1][trackster_id],
            'barycenter_z': barycenters[2][trackster_id],
            'barycenter_eta': barycenters[3][trackster_id],
            'barycenter_phi': barycenters[4][trackster_id]
        }

        # Include vertices_multiplicity if available
        if vertices_multiplicity is not None:
            trackster_info['vertices_multiplicity'] = vertices_multiplicity[trackster_id].tolist()

        tracksters_list.append(trackster_info)        
        
    # Store results for all tracksters
    results[root_name][event_id] = {
        "number_of_tracksters": len(tracksters_list),
        "tracksters": tracksters_list
    }
    if data_type == "CLUE3D":
        CLUE3D_results[root_name][event_id] = results[root_name][event_id]
    elif data_type == "sim":
        sim_results[root_name][event_id] = results[root_name][event_id]
    else:
        raise ValueError(f"Invalid data_type: {data_type}. Expected string of 'CLUE3D' or 'sim'.")


def load_GT_data(root_name, tree_name):

    file_path = f'rootfiles/{root_name}.root'
    with uproot.open(file_path) as file:
        tree = file[tree_name]
        branches = tree.arrays(['vertices_indexes', 'vertices_energy','barycenter_x','barycenter_y',
                                'barycenter_z','vertices_multiplicity','barycenter_eta','barycenter_phi'])      
    return branches

def get_event_GT_data(event_id, branches):
    return {
        "vertices_indexes": branches["vertices_indexes"][event_id],
        "vertices_energy": branches["vertices_energy"][event_id],
        "barycenter_x": branches["barycenter_x"][event_id],
        "barycenter_y": branches["barycenter_y"][event_id],
        "barycenter_z": branches["barycenter_z"][event_id],
        "vertices_multiplicity": branches["vertices_multiplicity"][event_id],
        "barycenter_eta": branches["barycenter_eta"][event_id],
        "barycenter_phi": branches["barycenter_phi"][event_id],
    }

def particle_Sim():

    for root_name in root_names:
        sim_results[root_name] = {}
        Raw_data_before_clustering[root_name] = {}

        #get branches for both trees
        sim_branches = load_GT_data(root_name, 'ticlDumper/simtrackstersCP;1')
        CLUEstering_branches = load_LC_data(root_name)
                
        for event_id in range(len(CLUEstering_branches)//2):
            # print(f"**********************************************************************")
            # print(f"\nEvent {event_id} of root {root_name}:")
            sim_event_data = get_event_GT_data(event_id, sim_branches)
            
            event_data = get_event_LC_data(event_id, CLUEstering_branches)
            Raw_data_before_clustering[root_name][event_id] = event_data
            
            if event_data.empty:  # Check if empty
                # print(f"No data found in Event {event_id} of {root_name}.")
                continue

            read_store_tracksters_properties(
                event_id=event_id,
                root_name=root_name,
                raw_data_df=event_data,
                vertices_indexes=sim_event_data['vertices_indexes'],
                vertices_energy=sim_event_data['vertices_energy'],
                barycenters=[sim_event_data['barycenter_x'],sim_event_data['barycenter_y'],sim_event_data['barycenter_z'],
                             sim_event_data['barycenter_eta'],sim_event_data['barycenter_phi']],
                vertices_multiplicity=sim_event_data['vertices_multiplicity'] if sim_event_data['vertices_multiplicity'] is not None else None,
                data_type="sim"
            )



def particle_CLUEStering():

    for root_name in root_names:
        CLUEstering_results[root_name] = {}
        Original_stat_values[root_name] = {}  # Ensure this is initialized
        Scaled_data_before_clustering[root_name] = {}
        CLUEstering_max_energy_tracksters[root_name] = {}
        all_events_grid_data[root_name] = {}
        
        CLUEstering_branches = load_LC_data(root_name)
        
        for event_id in range(len(CLUEstering_branches)//2):
            print(f"**********************************************************************")
            print(f"\nEvent {event_id} of root {root_name}:")

            event_data = Raw_data_before_clustering[root_name][event_id]

            if event_data.empty:  # Check if empty
                # print(f"No tracksters found in Event {event_id} of {root_name}.")
                continue

            # Only call store_stat_values if the event data is not empty
            store_stat_values(root_name, event_id, event_data)
            event_stats = Original_stat_values[root_name][event_id]
            
            # Scale data based on the specified scaling method
            event_data = scale_event_data(event_data, scale_method, event_stats)
            Scaled_data_before_clustering[root_name][event_id] = event_data

            # Save the event_data DataFrame to a CSV file after scaling
            output_folder = f'./ScaledEventData/{root_name}'
            os.makedirs(output_folder, exist_ok=True)  # Create the directory if it doesn't exist
            event_data.to_csv(os.path.join(output_folder, f'event_data_{event_id}.csv'), index=False)


            # List to store parameter configurations and sizes for this event
            event_parameters = []
            event_params_metrics = []
            data = Raw_data_before_clustering[root_name][event_id]
            
            for dc, rhoc, dm in product(dc_list, rhoc_list, dm_list):
                
                # Run clustering
                output_folder = f'./CLUEsteringOutput/{root_name}'
                paramset = [dc, rhoc, dm]
                clustering_output_path = apply_save_clustering(root_name, event_id, event_data, paramset, output_folder)
                
                # Process clustering output
                clustering_output_df = pd.read_csv(clustering_output_path)
                
                # Inverse scale the data using the corresponding inverse function
                scaled_back_data = inverse_scale_event_data(clustering_output_df, scale_method, event_stats)
                
                # Merge scaled back data with weights for trackster properties
                merged_df = pd.concat([scaled_back_data, pd.DataFrame({'weight': event_data['weight']})], axis=1)
                merged_df['indices'] = Scaled_data_before_clustering[root_name][event_id]['indices']
    
                # Calculate trackster properties
                grouped = merged_df.groupby('cluster_ids')
                CLUEstering_trackster_properties(root_name, event_id, data, grouped, dc, rhoc, dm, multi_particle, merge_threshold, efficiency_threshold, event_params_metrics)             
            
            all_events_grid_data[root_name][event_id] = event_params_metrics
            # print("all_events_grid_data:\n", all_events_grid_data)



if __name__ == "__main__":
    # Global dictionaries to store results
    Raw_data_before_clustering = {}
    Original_stat_values = {}
    Scaled_data_before_clustering = {}
    CLUEstering_results = {}
    CLUEstering_max_energy_tracksters = {}
    CLUE3D_results = {}
    CLUE3D_max_energy_tracksters = {}
    sim_results = {}
    sim_max_energy_tracksters = {}
    Sim_to_Reco_metrics = {}
    Reco_to_Sim_metrics = {}
    corresponding_tracksters_ids = {}
    all_events_grid_data = {}

    root_names = ['histo_two']
    dc_list = [0.2, 0.5, 0.7]
    rhoc_list = [4, 4.5, 5]
    dm_list = [0.5, 1, 2]
    merge_threshold = 0.6
    efficiency_threshold = 0.5
    multi_particle = True
    scale_method = 'all features by event z-score'  # Choose the desired scaling method
    
    # Step 2: Load the simulation data
    particle_Sim()
    
    # Step 1: Process the data with CLUEstering
    print(f"\nStarting CLUEstering processing...\n")
    particle_CLUEStering()

    # Step 3: Find the Optimum set of parameters
    print(f"\nFinding the Optimum set of parameters with this scaling")
    # find_optimum()
    find_optimum_with_cost_function()

    print(f"Pipeline completed.")
# Out:
# Processing sim Event 1 in histo_two with 2 tracksters...
# Processing sim Event 2 in histo_two with 2 tracksters...
# Processing sim Event 3 in histo_two with 2 tracksters...
# Processing sim Event 4 in histo_two with 2 tracksters...
# Processing sim Event 5 in histo_two with 2 tracksters...
# Processing sim Event 6 in histo_two with 2 tracksters...
# Processing sim Event 7 in histo_two with 2 tracksters...
# Processing sim Event 8 in histo_two with 2 tracksters...
# Processing sim Event 9 in histo_two with 2 tracksters...
# Processing sim Event 10 in histo_two with 2 tracksters...
# Processing sim Event 11 in histo_two with 2 tracksters...
# Processing sim Event 12 in histo_two with 2 tracksters...
# Processing sim Event 13 in histo_two with 2 tracksters...
# Processing sim Event 14 in histo_two with 2 tracksters...
# Processing sim Event 15 in histo_two with 2 tracksters...
# Processing sim Event 16 in histo_two with 2 tracksters...
# Processing sim Event 17 in histo_two with 2 tracksters...
# Processing sim Event 18 in histo_two with 2 tracksters...
# Processing sim Event 19 in histo_two with 2 tracksters...
# Processing sim Event 20 in histo_two with 2 tracksters...
# Processing sim Event 21 in histo_two with 2 tracksters...
# Processing sim Event 22 in histo_two with 2 tracksters...
# Processing sim Event 23 in histo_two with 2 tracksters...
# Processing sim Event 24 in histo_two with 2 tracksters...
# Processing sim Event 25 in histo_two with 2 tracksters...
# Processing sim Event 26 in histo_two with 2 tracksters...
# Processing sim Event 27 in histo_two with 2 tracksters...
# Processing sim Event 28 in histo_two with 2 tracksters...
# Processing sim Event 29 in histo_two with 2 tracksters...
# Processing sim Event 30 in histo_two with 2 tracksters...
# Processing sim Event 31 in histo_two with 2 tracksters...
# Processing sim Event 32 in histo_two with 2 tracksters...
# Processing sim Event 33 in histo_two with 2 tracksters...
# Processing sim Event 34 in histo_two with 2 tracksters...
# Processing sim Event 35 in histo_two with 2 tracksters...
# Processing sim Event 37 in histo_two with 2 tracksters...
# Processing sim Event 38 in histo_two with 2 tracksters...
# Processing sim Event 39 in histo_two with 2 tracksters...
# Processing sim Event 40 in histo_two with 2 tracksters...
# Processing sim Event 41 in histo_two with 2 tracksters...
# Processing sim Event 42 in histo_two with 2 tracksters...
# Processing sim Event 43 in histo_two with 2 tracksters...
# Processing sim Event 44 in histo_two with 2 tracksters...
# Processing sim Event 45 in histo_two with 2 tracksters...
# Processing sim Event 46 in histo_two with 2 tracksters...
# Processing sim Event 47 in histo_two with 2 tracksters...
# Processing sim Event 48 in histo_two with 2 tracksters...
# Processing sim Event 49 in histo_two with 2 tracksters...
# Processing sim Event 50 in histo_two with 2 tracksters...
# Processing sim Event 51 in histo_two with 2 tracksters...
# Processing sim Event 52 in histo_two with 2 tracksters...
# Processing sim Event 53 in histo_two with 2 tracksters...
# Processing sim Event 54 in histo_two with 2 tracksters...
# Processing sim Event 55 in histo_two with 2 tracksters...
# Processing sim Event 56 in histo_two with 2 tracksters...
# Processing sim Event 57 in histo_two with 2 tracksters...
# Processing sim Event 58 in histo_two with 2 tracksters...
# Processing sim Event 59 in histo_two with 2 tracksters...
# Processing sim Event 60 in histo_two with 2 tracksters...
# Processing sim Event 61 in histo_two with 2 tracksters...
# Processing sim Event 62 in histo_two with 2 tracksters...
# Processing sim Event 63 in histo_two with 2 tracksters...
# Processing sim Event 64 in histo_two with 2 tracksters...
# Processing sim Event 65 in histo_two with 2 tracksters...
# Processing sim Event 66 in histo_two with 2 tracksters...
# Processing sim Event 67 in histo_two with 2 tracksters...
# Processing sim Event 68 in histo_two with 2 tracksters...
# Processing sim Event 69 in histo_two with 2 tracksters...
# Processing sim Event 70 in histo_two with 2 tracksters...
# Processing sim Event 71 in histo_two with 2 tracksters...
# Processing sim Event 72 in histo_two with 2 tracksters...
# Processing sim Event 73 in histo_two with 2 tracksters...
# Processing sim Event 74 in histo_two with 2 tracksters...
# Processing sim Event 75 in histo_two with 2 tracksters...
# Processing sim Event 76 in histo_two with 2 tracksters...
# Processing sim Event 77 in histo_two with 2 tracksters...
# Processing sim Event 78 in histo_two with 2 tracksters...
# Processing sim Event 79 in histo_two with 2 tracksters...
# Processing sim Event 80 in histo_two with 1 tracksters...
# Processing sim Event 81 in histo_two with 2 tracksters...
# Processing sim Event 83 in histo_two with 2 tracksters...
# Processing sim Event 84 in histo_two with 2 tracksters...
# Processing sim Event 85 in histo_two with 2 tracksters...
# Processing sim Event 86 in histo_two with 2 tracksters...
# Processing sim Event 87 in histo_two with 2 tracksters...
# Processing sim Event 88 in histo_two with 2 tracksters...
# Processing sim Event 89 in histo_two with 2 tracksters...
# Processing sim Event 90 in histo_two with 1 tracksters...
# Processing sim Event 91 in histo_two with 2 tracksters...
# Processing sim Event 92 in histo_two with 2 tracksters...
# Processing sim Event 93 in histo_two with 2 tracksters...
# Processing sim Event 94 in histo_two with 2 tracksters...
# Processing sim Event 95 in histo_two with 2 tracksters...
# Processing sim Event 96 in histo_two with 2 tracksters...
# Processing sim Event 97 in histo_two with 2 tracksters...
# Processing sim Event 98 in histo_two with 2 tracksters...
# Processing sim Event 99 in histo_two with 2 tracksters...
# Processing sim Event 100 in histo_two with 2 tracksters...
# Processing sim Event 101 in histo_two with 2 tracksters...
# Processing sim Event 102 in histo_two with 2 tracksters...
# Processing sim Event 103 in histo_two with 2 tracksters...
# Processing sim Event 104 in histo_two with 2 tracksters...
# Processing sim Event 105 in histo_two with 2 tracksters...
# Processing sim Event 106 in histo_two with 2 tracksters...
# Processing sim Event 107 in histo_two with 2 tracksters...
# Processing sim Event 108 in histo_two with 2 tracksters...
# Processing sim Event 109 in histo_two with 2 tracksters...
# Processing sim Event 110 in histo_two with 2 tracksters...
# Processing sim Event 111 in histo_two with 2 tracksters...
# Processing sim Event 112 in histo_two with 2 tracksters...
# Processing sim Event 113 in histo_two with 2 tracksters...
# Processing sim Event 114 in histo_two with 1 tracksters...
# Processing sim Event 115 in histo_two with 2 tracksters...
# Processing sim Event 116 in histo_two with 2 tracksters...
# Processing sim Event 117 in histo_two with 2 tracksters...
# Processing sim Event 118 in histo_two with 2 tracksters...
# Processing sim Event 119 in histo_two with 2 tracksters...
# Processing sim Event 120 in histo_two with 2 tracksters...
# Processing sim Event 121 in histo_two with 2 tracksters...
# Processing sim Event 122 in histo_two with 2 tracksters...
# Processing sim Event 123 in histo_two with 2 tracksters...
# Processing sim Event 124 in histo_two with 2 tracksters...
# Processing sim Event 125 in histo_two with 2 tracksters...
# Processing sim Event 126 in histo_two with 2 tracksters...
# Processing sim Event 127 in histo_two with 2 tracksters...
# Processing sim Event 128 in histo_two with 2 tracksters...
# Processing sim Event 129 in histo_two with 2 tracksters...
# Processing sim Event 130 in histo_two with 2 tracksters...
# Processing sim Event 131 in histo_two with 2 tracksters...
# Processing sim Event 132 in histo_two with 2 tracksters...
# Processing sim Event 133 in histo_two with 2 tracksters...
# Processing sim Event 134 in histo_two with 2 tracksters...
# Processing sim Event 135 in histo_two with 2 tracksters...
# Processing sim Event 136 in histo_two with 2 tracksters...
# Processing sim Event 137 in histo_two with 2 tracksters...
# Processing sim Event 138 in histo_two with 2 tracksters...
# Processing sim Event 139 in histo_two with 2 tracksters...
# Processing sim Event 140 in histo_two with 2 tracksters...
# Processing sim Event 141 in histo_two with 2 tracksters...
# Processing sim Event 142 in histo_two with 2 tracksters...
# Processing sim Event 143 in histo_two with 2 tracksters...
# Processing sim Event 144 in histo_two with 2 tracksters...
# Processing sim Event 145 in histo_two with 2 tracksters...
# Processing sim Event 146 in histo_two with 2 tracksters...
# Processing sim Event 147 in histo_two with 2 tracksters...
# Processing sim Event 148 in histo_two with 2 tracksters...
# Processing sim Event 149 in histo_two with 1 tracksters...
# Processing sim Event 150 in histo_two with 2 tracksters...
# Processing sim Event 151 in histo_two with 2 tracksters...
# Processing sim Event 152 in histo_two with 2 tracksters...
# Processing sim Event 153 in histo_two with 2 tracksters...
# Processing sim Event 154 in histo_two with 2 tracksters...
# Processing sim Event 155 in histo_two with 2 tracksters...
# Processing sim Event 156 in histo_two with 2 tracksters...
# Processing sim Event 157 in histo_two with 2 tracksters...
# Processing sim Event 158 in histo_two with 2 tracksters...
# Processing sim Event 159 in histo_two with 2 tracksters...
# Processing sim Event 160 in histo_two with 2 tracksters...
# Processing sim Event 161 in histo_two with 2 tracksters...
# Processing sim Event 162 in histo_two with 2 tracksters...
# Processing sim Event 163 in histo_two with 2 tracksters...
# Processing sim Event 164 in histo_two with 2 tracksters...
# Processing sim Event 165 in histo_two with 2 tracksters...
# Processing sim Event 166 in histo_two with 2 tracksters...
# Processing sim Event 167 in histo_two with 2 tracksters...
# Processing sim Event 168 in histo_two with 2 tracksters...
# Processing sim Event 169 in histo_two with 2 tracksters...
# Processing sim Event 170 in histo_two with 2 tracksters...
# Processing sim Event 171 in histo_two with 2 tracksters...
# Processing sim Event 172 in histo_two with 2 tracksters...
# Processing sim Event 173 in histo_two with 2 tracksters...
# Processing sim Event 174 in histo_two with 2 tracksters...
# Processing sim Event 175 in histo_two with 2 tracksters...
# Processing sim Event 176 in histo_two with 2 tracksters...
# Processing sim Event 177 in histo_two with 2 tracksters...
# Processing sim Event 178 in histo_two with 2 tracksters...
# Processing sim Event 179 in histo_two with 2 tracksters...
# Processing sim Event 180 in histo_two with 2 tracksters...
# Processing sim Event 181 in histo_two with 2 tracksters...
# Processing sim Event 182 in histo_two with 2 tracksters...
# Processing sim Event 183 in histo_two with 2 tracksters...
# Processing sim Event 184 in histo_two with 2 tracksters...
# Processing sim Event 185 in histo_two with 2 tracksters...
# Processing sim Event 186 in histo_two with 2 tracksters...
# Processing sim Event 187 in histo_two with 2 tracksters...
# Processing sim Event 188 in histo_two with 2 tracksters...
# Processing sim Event 189 in histo_two with 2 tracksters...
# Processing sim Event 190 in histo_two with 2 tracksters...
# Processing sim Event 191 in histo_two with 2 tracksters...
# Processing sim Event 192 in histo_two with 2 tracksters...
# Processing sim Event 193 in histo_two with 2 tracksters...
# Processing sim Event 194 in histo_two with 2 tracksters...
# Processing sim Event 195 in histo_two with 2 tracksters...
# Processing sim Event 196 in histo_two with 2 tracksters...
# Processing sim Event 197 in histo_two with 2 tracksters...
# Processing sim Event 198 in histo_two with 2 tracksters...
# Processing sim Event 199 in histo_two with 2 tracksters...
# Processing sim Event 200 in histo_two with 2 tracksters...
# Processing sim Event 201 in histo_two with 2 tracksters...
# Processing sim Event 202 in histo_two with 2 tracksters...
# Processing sim Event 203 in histo_two with 2 tracksters...
# Processing sim Event 204 in histo_two with 2 tracksters...
# Processing sim Event 205 in histo_two with 2 tracksters...
# Processing sim Event 206 in histo_two with 2 tracksters...
# Processing sim Event 207 in histo_two with 2 tracksters...
# Processing sim Event 208 in histo_two with 2 tracksters...
# Processing sim Event 209 in histo_two with 2 tracksters...
# Processing sim Event 210 in histo_two with 2 tracksters...
# Processing sim Event 211 in histo_two with 2 tracksters...
# Processing sim Event 212 in histo_two with 2 tracksters...
# Processing sim Event 213 in histo_two with 2 tracksters...
# Processing sim Event 214 in histo_two with 2 tracksters...
# Processing sim Event 215 in histo_two with 2 tracksters...
# Processing sim Event 216 in histo_two with 2 tracksters...
# Processing sim Event 217 in histo_two with 2 tracksters...
# Processing sim Event 218 in histo_two with 2 tracksters...
# Processing sim Event 219 in histo_two with 2 tracksters...
# Processing sim Event 220 in histo_two with 2 tracksters...
# Processing sim Event 221 in histo_two with 2 tracksters...
# Processing sim Event 222 in histo_two with 2 tracksters...
# Processing sim Event 223 in histo_two with 2 tracksters...
# Processing sim Event 224 in histo_two with 2 tracksters...
# Processing sim Event 225 in histo_two with 2 tracksters...
# Processing sim Event 226 in histo_two with 2 tracksters...
# Processing sim Event 227 in histo_two with 2 tracksters...
# Processing sim Event 228 in histo_two with 2 tracksters...
# Processing sim Event 229 in histo_two with 2 tracksters...
# Processing sim Event 230 in histo_two with 2 tracksters...
# Processing sim Event 231 in histo_two with 2 tracksters...
# Processing sim Event 232 in histo_two with 2 tracksters...
# Processing sim Event 233 in histo_two with 2 tracksters...
# Processing sim Event 234 in histo_two with 2 tracksters...
# Processing sim Event 235 in histo_two with 2 tracksters...
# Processing sim Event 236 in histo_two with 2 tracksters...
# Processing sim Event 237 in histo_two with 2 tracksters...
# Processing sim Event 238 in histo_two with 2 tracksters...
# Processing sim Event 239 in histo_two with 2 tracksters...
# Processing sim Event 240 in histo_two with 2 tracksters...
# Processing sim Event 241 in histo_two with 2 tracksters...
# Processing sim Event 242 in histo_two with 2 tracksters...
# Processing sim Event 243 in histo_two with 2 tracksters...
# Processing sim Event 244 in histo_two with 2 tracksters...
# Processing sim Event 245 in histo_two with 2 tracksters...
# Processing sim Event 246 in histo_two with 2 tracksters...
# Processing sim Event 247 in histo_two with 2 tracksters...
# Processing sim Event 248 in histo_two with 2 tracksters...
# Processing sim Event 249 in histo_two with 2 tracksters...
# Processing sim Event 250 in histo_two with 2 tracksters...
# Processing sim Event 251 in histo_two with 2 tracksters...
# Processing sim Event 252 in histo_two with 2 tracksters...
# Processing sim Event 253 in histo_two with 2 tracksters...
# Processing sim Event 254 in histo_two with 2 tracksters...
# Processing sim Event 255 in histo_two with 2 tracksters...
# Processing sim Event 256 in histo_two with 2 tracksters...
# Processing sim Event 257 in histo_two with 2 tracksters...
# Processing sim Event 258 in histo_two with 2 tracksters...
# Processing sim Event 259 in histo_two with 2 tracksters...
# Processing sim Event 260 in histo_two with 2 tracksters...
# Processing sim Event 261 in histo_two with 2 tracksters...
# Processing sim Event 262 in histo_two with 2 tracksters...
# Processing sim Event 263 in histo_two with 2 tracksters...
# Processing sim Event 264 in histo_two with 2 tracksters...
# Processing sim Event 265 in histo_two with 2 tracksters...
# Processing sim Event 266 in histo_two with 2 tracksters...
# Processing sim Event 267 in histo_two with 2 tracksters...
# Processing sim Event 268 in histo_two with 2 tracksters...
# Processing sim Event 269 in histo_two with 1 tracksters...
# Processing sim Event 270 in histo_two with 2 tracksters...
# Processing sim Event 271 in histo_two with 2 tracksters...
# Processing sim Event 272 in histo_two with 2 tracksters...
# Processing sim Event 273 in histo_two with 2 tracksters...
# Processing sim Event 274 in histo_two with 2 tracksters...
# Processing sim Event 275 in histo_two with 2 tracksters...
# Processing sim Event 276 in histo_two with 2 tracksters...
# Processing sim Event 277 in histo_two with 2 tracksters...
# Processing sim Event 278 in histo_two with 2 tracksters...
# Processing sim Event 279 in histo_two with 2 tracksters...
# Processing sim Event 280 in histo_two with 2 tracksters...
# Processing sim Event 281 in histo_two with 2 tracksters...
# Processing sim Event 282 in histo_two with 2 tracksters...
# Processing sim Event 283 in histo_two with 2 tracksters...
# Processing sim Event 284 in histo_two with 2 tracksters...
# Processing sim Event 285 in histo_two with 2 tracksters...
# Processing sim Event 286 in histo_two with 2 tracksters...
# Processing sim Event 287 in histo_two with 2 tracksters...
# Processing sim Event 288 in histo_two with 2 tracksters...
# Processing sim Event 289 in histo_two with 2 tracksters...
# Processing sim Event 290 in histo_two with 2 tracksters...
# Processing sim Event 291 in histo_two with 2 tracksters...
# Processing sim Event 292 in histo_two with 2 tracksters...
# Processing sim Event 293 in histo_two with 2 tracksters...
# Processing sim Event 294 in histo_two with 1 tracksters...
# Processing sim Event 295 in histo_two with 2 tracksters...
# Processing sim Event 296 in histo_two with 2 tracksters...
# Processing sim Event 297 in histo_two with 2 tracksters...
# Processing sim Event 298 in histo_two with 2 tracksters...
# Processing sim Event 299 in histo_two with 2 tracksters...
# Processing sim Event 300 in histo_two with 2 tracksters...
# Processing sim Event 301 in histo_two with 2 tracksters...
# Processing sim Event 302 in histo_two with 2 tracksters...
# Processing sim Event 303 in histo_two with 2 tracksters...
# Processing sim Event 304 in histo_two with 2 tracksters...
# Processing sim Event 305 in histo_two with 2 tracksters...
# Processing sim Event 306 in histo_two with 2 tracksters...
# Processing sim Event 307 in histo_two with 2 tracksters...
# Processing sim Event 308 in histo_two with 2 tracksters...
# Processing sim Event 309 in histo_two with 2 tracksters...
# Processing sim Event 310 in histo_two with 2 tracksters...
# Processing sim Event 311 in histo_two with 2 tracksters...
# Processing sim Event 312 in histo_two with 2 tracksters...
# Processing sim Event 313 in histo_two with 2 tracksters...
# Processing sim Event 314 in histo_two with 2 tracksters...
# Processing sim Event 315 in histo_two with 2 tracksters...
# Processing sim Event 316 in histo_two with 2 tracksters...
# Processing sim Event 317 in histo_two with 2 tracksters...
# Processing sim Event 318 in histo_two with 2 tracksters...
# Processing sim Event 319 in histo_two with 2 tracksters...
# Processing sim Event 320 in histo_two with 2 tracksters...
# Processing sim Event 321 in histo_two with 2 tracksters...
# Processing sim Event 322 in histo_two with 2 tracksters...
# Processing sim Event 323 in histo_two with 2 tracksters...
# Processing sim Event 324 in histo_two with 2 tracksters...
# Processing sim Event 325 in histo_two with 2 tracksters...
# Processing sim Event 326 in histo_two with 2 tracksters...
# Processing sim Event 327 in histo_two with 2 tracksters...
# Processing sim Event 328 in histo_two with 2 tracksters...
# Processing sim Event 329 in histo_two with 2 tracksters...
# Processing sim Event 330 in histo_two with 2 tracksters...
# Processing sim Event 331 in histo_two with 2 tracksters...
# Processing sim Event 332 in histo_two with 2 tracksters...
# Processing sim Event 333 in histo_two with 2 tracksters...
# Processing sim Event 334 in histo_two with 2 tracksters...
# Processing sim Event 335 in histo_two with 2 tracksters...
# Processing sim Event 336 in histo_two with 2 tracksters...
# Processing sim Event 337 in histo_two with 2 tracksters...
# Processing sim Event 338 in histo_two with 2 tracksters...
# Processing sim Event 339 in histo_two with 2 tracksters...
# Processing sim Event 340 in histo_two with 2 tracksters...
# Processing sim Event 341 in histo_two with 2 tracksters...
# Processing sim Event 342 in histo_two with 2 tracksters...
# Processing sim Event 343 in histo_two with 2 tracksters...
# Processing sim Event 344 in histo_two with 2 tracksters...
# Processing sim Event 345 in histo_two with 2 tracksters...
# Processing sim Event 346 in histo_two with 2 tracksters...
# Processing sim Event 347 in histo_two with 2 tracksters...
# Processing sim Event 348 in histo_two with 2 tracksters...
# Processing sim Event 349 in histo_two with 2 tracksters...
# Processing sim Event 350 in histo_two with 2 tracksters...
# Processing sim Event 351 in histo_two with 2 tracksters...
# Processing sim Event 352 in histo_two with 2 tracksters...
# Processing sim Event 353 in histo_two with 2 tracksters...
# Processing sim Event 354 in histo_two with 2 tracksters...
# Processing sim Event 355 in histo_two with 2 tracksters...
# Processing sim Event 356 in histo_two with 2 tracksters...
# Processing sim Event 357 in histo_two with 2 tracksters...
# Processing sim Event 358 in histo_two with 2 tracksters...
# Processing sim Event 359 in histo_two with 1 tracksters...
# Processing sim Event 360 in histo_two with 2 tracksters...
# Processing sim Event 361 in histo_two with 2 tracksters...
# Processing sim Event 362 in histo_two with 2 tracksters...
# Processing sim Event 363 in histo_two with 2 tracksters...
# Processing sim Event 364 in histo_two with 2 tracksters...
# Processing sim Event 365 in histo_two with 2 tracksters...
# Processing sim Event 366 in histo_two with 2 tracksters...
# Processing sim Event 367 in histo_two with 2 tracksters...
# Processing sim Event 368 in histo_two with 1 tracksters...
# Processing sim Event 369 in histo_two with 2 tracksters...
# Processing sim Event 370 in histo_two with 2 tracksters...
# Processing sim Event 371 in histo_two with 2 tracksters...
# Processing sim Event 372 in histo_two with 2 tracksters...
# Processing sim Event 373 in histo_two with 2 tracksters...
# Processing sim Event 374 in histo_two with 2 tracksters...
# Processing sim Event 375 in histo_two with 2 tracksters...
# Processing sim Event 376 in histo_two with 2 tracksters...
# Processing sim Event 377 in histo_two with 2 tracksters...
# Processing sim Event 378 in histo_two with 2 tracksters...
# Processing sim Event 379 in histo_two with 2 tracksters...
# Processing sim Event 380 in histo_two with 2 tracksters...
# Processing sim Event 381 in histo_two with 2 tracksters...
# Processing sim Event 382 in histo_two with 2 tracksters...
# Processing sim Event 383 in histo_two with 1 tracksters...
# Processing sim Event 384 in histo_two with 2 tracksters...
# Processing sim Event 385 in histo_two with 2 tracksters...
# Processing sim Event 386 in histo_two with 2 tracksters...
# Processing sim Event 387 in histo_two with 2 tracksters...
# Processing sim Event 388 in histo_two with 2 tracksters...
# Processing sim Event 389 in histo_two with 2 tracksters...
# Processing sim Event 390 in histo_two with 2 tracksters...
# Processing sim Event 391 in histo_two with 2 tracksters...
# Processing sim Event 392 in histo_two with 2 tracksters...
# Processing sim Event 393 in histo_two with 2 tracksters...
# Processing sim Event 394 in histo_two with 2 tracksters...
# Processing sim Event 395 in histo_two with 1 tracksters...
# Processing sim Event 396 in histo_two with 2 tracksters...
# Processing sim Event 397 in histo_two with 2 tracksters...
# Processing sim Event 398 in histo_two with 2 tracksters...
# Processing sim Event 399 in histo_two with 2 tracksters...
# Processing sim Event 400 in histo_two with 2 tracksters...
# Processing sim Event 401 in histo_two with 2 tracksters...
# Processing sim Event 402 in histo_two with 2 tracksters...
# Processing sim Event 403 in histo_two with 2 tracksters...
# Processing sim Event 404 in histo_two with 2 tracksters...
# Processing sim Event 405 in histo_two with 2 tracksters...
# Processing sim Event 406 in histo_two with 2 tracksters...
# Processing sim Event 407 in histo_two with 2 tracksters...
# Processing sim Event 408 in histo_two with 2 tracksters...
# Processing sim Event 409 in histo_two with 2 tracksters...
# Processing sim Event 410 in histo_two with 2 tracksters...
# Processing sim Event 411 in histo_two with 2 tracksters...
# Processing sim Event 412 in histo_two with 2 tracksters...
# Processing sim Event 413 in histo_two with 2 tracksters...
# Processing sim Event 414 in histo_two with 2 tracksters...
# Processing sim Event 415 in histo_two with 2 tracksters...
# Processing sim Event 416 in histo_two with 2 tracksters...
# Processing sim Event 417 in histo_two with 2 tracksters...
# Processing sim Event 418 in histo_two with 2 tracksters...
# Processing sim Event 419 in histo_two with 2 tracksters...
# Processing sim Event 420 in histo_two with 2 tracksters...
# Processing sim Event 421 in histo_two with 2 tracksters...
# Processing sim Event 422 in histo_two with 2 tracksters...
# Processing sim Event 423 in histo_two with 2 tracksters...
# Processing sim Event 424 in histo_two with 2 tracksters...
# Processing sim Event 425 in histo_two with 2 tracksters...
# Processing sim Event 426 in histo_two with 2 tracksters...
# Processing sim Event 427 in histo_two with 2 tracksters...
# Processing sim Event 428 in histo_two with 2 tracksters...
# Processing sim Event 429 in histo_two with 2 tracksters...
# Processing sim Event 430 in histo_two with 2 tracksters...
# Processing sim Event 431 in histo_two with 2 tracksters...
# Processing sim Event 432 in histo_two with 2 tracksters...
# Processing sim Event 433 in histo_two with 2 tracksters...
# Processing sim Event 434 in histo_two with 2 tracksters...
# Processing sim Event 435 in histo_two with 2 tracksters...
# Processing sim Event 436 in histo_two with 2 tracksters...
# Processing sim Event 437 in histo_two with 2 tracksters...
# Processing sim Event 438 in histo_two with 2 tracksters...
# Processing sim Event 439 in histo_two with 2 tracksters...
# Processing sim Event 440 in histo_two with 2 tracksters...
# Processing sim Event 441 in histo_two with 2 tracksters...
# Processing sim Event 442 in histo_two with 2 tracksters...
# Processing sim Event 443 in histo_two with 2 tracksters...
# Processing sim Event 444 in histo_two with 2 tracksters...
# Processing sim Event 445 in histo_two with 2 tracksters...
# Processing sim Event 446 in histo_two with 2 tracksters...
# Processing sim Event 447 in histo_two with 2 tracksters...
# Processing sim Event 448 in histo_two with 2 tracksters...
# Processing sim Event 449 in histo_two with 2 tracksters...
# Processing sim Event 450 in histo_two with 2 tracksters...
# Processing sim Event 451 in histo_two with 1 tracksters...
# Processing sim Event 452 in histo_two with 2 tracksters...
# Processing sim Event 453 in histo_two with 2 tracksters...
# Processing sim Event 454 in histo_two with 2 tracksters...
# Processing sim Event 455 in histo_two with 2 tracksters...
# Processing sim Event 456 in histo_two with 2 tracksters...
# Processing sim Event 457 in histo_two with 2 tracksters...
# Processing sim Event 458 in histo_two with 2 tracksters...
# Processing sim Event 459 in histo_two with 2 tracksters...
# Processing sim Event 460 in histo_two with 2 tracksters...
# Processing sim Event 461 in histo_two with 2 tracksters...
# Processing sim Event 462 in histo_two with 2 tracksters...
# Processing sim Event 463 in histo_two with 2 tracksters...
# Processing sim Event 464 in histo_two with 2 tracksters...
# Processing sim Event 465 in histo_two with 2 tracksters...
# Processing sim Event 466 in histo_two with 2 tracksters...
# Processing sim Event 467 in histo_two with 2 tracksters...
# Processing sim Event 468 in histo_two with 2 tracksters...
# Processing sim Event 469 in histo_two with 2 tracksters...
# Processing sim Event 470 in histo_two with 2 tracksters...
# Processing sim Event 471 in histo_two with 2 tracksters...
# Processing sim Event 472 in histo_two with 2 tracksters...
# Processing sim Event 473 in histo_two with 2 tracksters...
# Processing sim Event 474 in histo_two with 2 tracksters...
# Processing sim Event 475 in histo_two with 2 tracksters...
# Processing sim Event 476 in histo_two with 2 tracksters...
# Processing sim Event 477 in histo_two with 2 tracksters...
# Processing sim Event 478 in histo_two with 2 tracksters...
# Processing sim Event 479 in histo_two with 2 tracksters...
# Processing sim Event 480 in histo_two with 2 tracksters...
# Processing sim Event 481 in histo_two with 2 tracksters...
# Processing sim Event 482 in histo_two with 2 tracksters...
# Processing sim Event 483 in histo_two with 2 tracksters...
# Processing sim Event 484 in histo_two with 2 tracksters...
# Processing sim Event 485 in histo_two with 2 tracksters...
# Processing sim Event 486 in histo_two with 2 tracksters...
# Processing sim Event 487 in histo_two with 2 tracksters...
# Processing sim Event 488 in histo_two with 1 tracksters...
# Processing sim Event 489 in histo_two with 2 tracksters...
# Processing sim Event 490 in histo_two with 2 tracksters...
# Processing sim Event 491 in histo_two with 2 tracksters...
# Processing sim Event 492 in histo_two with 2 tracksters...
# Processing sim Event 493 in histo_two with 2 tracksters...
# Processing sim Event 494 in histo_two with 2 tracksters...
# Processing sim Event 495 in histo_two with 2 tracksters...
# Processing sim Event 496 in histo_two with 2 tracksters...
# Processing sim Event 497 in histo_two with 2 tracksters...
# Processing sim Event 498 in histo_two with 2 tracksters...
# Processing sim Event 499 in histo_two with 2 tracksters...
#
# Starting CLUEstering processing...
#
# **********************************************************************
#
# Event 0 of root histo_two:
# **********************************************************************
#
# Event 1 of root histo_two:
# **********************************************************************
#
# Event 2 of root histo_two:
# **********************************************************************
#
# Event 3 of root histo_two:
# **********************************************************************
#
# Event 4 of root histo_two:
# **********************************************************************
#
# Event 5 of root histo_two:
# **********************************************************************
#
# Event 6 of root histo_two:
# **********************************************************************
#
# Event 7 of root histo_two:
# **********************************************************************
#
# Event 8 of root histo_two:
# **********************************************************************
#
# Event 9 of root histo_two:
# **********************************************************************
#
# Event 10 of root histo_two:
# **********************************************************************
#
# Event 11 of root histo_two:
# **********************************************************************
#
# Event 12 of root histo_two:
# **********************************************************************
#
# Event 13 of root histo_two:
# **********************************************************************
#
# Event 14 of root histo_two:
# **********************************************************************
#
# Event 15 of root histo_two:
# **********************************************************************
#
# Event 16 of root histo_two:
# **********************************************************************
#
# Event 17 of root histo_two:
# **********************************************************************
#
# Event 18 of root histo_two:
# **********************************************************************
#
# Event 19 of root histo_two:
# **********************************************************************
#
# Event 20 of root histo_two:
# **********************************************************************
#
# Event 21 of root histo_two:
# **********************************************************************
#
# Event 22 of root histo_two:
# **********************************************************************
#
# Event 23 of root histo_two:
# **********************************************************************
#
# Event 24 of root histo_two:
# **********************************************************************
#
# Event 25 of root histo_two:
# **********************************************************************
#
# Event 26 of root histo_two:
# **********************************************************************
#
# Event 27 of root histo_two:
# **********************************************************************
#
# Event 28 of root histo_two:
# **********************************************************************
#
# Event 29 of root histo_two:
# **********************************************************************
#
# Event 30 of root histo_two:
# **********************************************************************
#
# Event 31 of root histo_two:
# **********************************************************************
#
# Event 32 of root histo_two:
# **********************************************************************
#
# Event 33 of root histo_two:
# **********************************************************************
#
# Event 34 of root histo_two:
# **********************************************************************
#
# Event 35 of root histo_two:
# **********************************************************************
#
# Event 36 of root histo_two:
# **********************************************************************
#
# Event 37 of root histo_two:
# **********************************************************************
#
# Event 38 of root histo_two:
# **********************************************************************
#
# Event 39 of root histo_two:
# **********************************************************************
#
# Event 40 of root histo_two:
# **********************************************************************
#
# Event 41 of root histo_two:
# **********************************************************************
#
# Event 42 of root histo_two:
# **********************************************************************
#
# Event 43 of root histo_two:
# **********************************************************************
#
# Event 44 of root histo_two:
# **********************************************************************
#
# Event 45 of root histo_two:
# **********************************************************************
#
# Event 46 of root histo_two:
# **********************************************************************
#
# Event 47 of root histo_two:
# **********************************************************************
#
# Event 48 of root histo_two:
# **********************************************************************
#
# Event 49 of root histo_two:
# **********************************************************************
#
# Event 50 of root histo_two:
# **********************************************************************
#
# Event 51 of root histo_two:
# **********************************************************************
#
# Event 52 of root histo_two:
# **********************************************************************
#
# Event 53 of root histo_two:
# **********************************************************************
#
# Event 54 of root histo_two:
# **********************************************************************
#
# Event 55 of root histo_two:
# **********************************************************************
#
# Event 56 of root histo_two:
# **********************************************************************
#
# Event 57 of root histo_two:
# **********************************************************************
#
# Event 58 of root histo_two:
# **********************************************************************
#
# Event 59 of root histo_two:
# **********************************************************************
#
# Event 60 of root histo_two:
# **********************************************************************
#
# Event 61 of root histo_two:
# **********************************************************************
#
# Event 62 of root histo_two:
# **********************************************************************
#
# Event 63 of root histo_two:
# **********************************************************************
#
# Event 64 of root histo_two:
# **********************************************************************
#
# Event 65 of root histo_two:
# **********************************************************************
#
# Event 66 of root histo_two:
# **********************************************************************
#
# Event 67 of root histo_two:
# **********************************************************************
#
# Event 68 of root histo_two:
# **********************************************************************
#
# Event 69 of root histo_two:
# **********************************************************************
#
# Event 70 of root histo_two:
# **********************************************************************
#
# Event 71 of root histo_two:
# **********************************************************************
#
# Event 72 of root histo_two:
# **********************************************************************
#
# Event 73 of root histo_two:
# **********************************************************************
#
# Event 74 of root histo_two:
# **********************************************************************
#
# Event 75 of root histo_two:
# **********************************************************************
#
# Event 76 of root histo_two:
# **********************************************************************
#
# Event 77 of root histo_two:
# **********************************************************************
#
# Event 78 of root histo_two:
# **********************************************************************
#
# Event 79 of root histo_two:
# **********************************************************************
#
# Event 80 of root histo_two:
# **********************************************************************
#
# Event 81 of root histo_two:
# **********************************************************************
#
# Event 82 of root histo_two:
# **********************************************************************
#
# Event 83 of root histo_two:
# **********************************************************************
#
# Event 84 of root histo_two:
# **********************************************************************
#
# Event 85 of root histo_two:
# **********************************************************************
#
# Event 86 of root histo_two:
# **********************************************************************
#
# Event 87 of root histo_two:
# **********************************************************************
#
# Event 88 of root histo_two:
# **********************************************************************
#
# Event 89 of root histo_two:
# **********************************************************************
#
# Event 90 of root histo_two:
# **********************************************************************
#
# Event 91 of root histo_two:
# **********************************************************************
#
# Event 92 of root histo_two:
# **********************************************************************
#
# Event 93 of root histo_two:
# **********************************************************************
#
# Event 94 of root histo_two:
# **********************************************************************
#
# Event 95 of root histo_two:
# **********************************************************************
#
# Event 96 of root histo_two:
# **********************************************************************
#
# Event 97 of root histo_two:
# **********************************************************************
#
# Event 98 of root histo_two:
# **********************************************************************
#
# Event 99 of root histo_two:
# **********************************************************************
#
# Event 100 of root histo_two:
# **********************************************************************
#
# Event 101 of root histo_two:
# **********************************************************************
#
# Event 102 of root histo_two:
# **********************************************************************
#
# Event 103 of root histo_two:
# **********************************************************************
#
# Event 104 of root histo_two:
# **********************************************************************
#
# Event 105 of root histo_two:
# **********************************************************************
#
# Event 106 of root histo_two:
# **********************************************************************
#
# Event 107 of root histo_two:
# **********************************************************************
#
# Event 108 of root histo_two:
# **********************************************************************
#
# Event 109 of root histo_two:
# **********************************************************************
#
# Event 110 of root histo_two:
# **********************************************************************
#
# Event 111 of root histo_two:
# **********************************************************************
#
# Event 112 of root histo_two:
# **********************************************************************
#
# Event 113 of root histo_two:
# **********************************************************************
#
# Event 114 of root histo_two:
# **********************************************************************
#
# Event 115 of root histo_two:
# **********************************************************************
#
# Event 116 of root histo_two:
# **********************************************************************
#
# Event 117 of root histo_two:
# **********************************************************************
#
# Event 118 of root histo_two:
# **********************************************************************
#
# Event 119 of root histo_two:
# **********************************************************************
#
# Event 120 of root histo_two:
# **********************************************************************
#
# Event 121 of root histo_two:
# **********************************************************************
#
# Event 122 of root histo_two:
# **********************************************************************
#
# Event 123 of root histo_two:
# **********************************************************************
#
# Event 124 of root histo_two:
# **********************************************************************
#
# Event 125 of root histo_two:
# **********************************************************************
#
# Event 126 of root histo_two:
# **********************************************************************
#
# Event 127 of root histo_two:
# **********************************************************************
#
# Event 128 of root histo_two:
# **********************************************************************
#
# Event 129 of root histo_two:
# **********************************************************************
#
# Event 130 of root histo_two:
# **********************************************************************
#
# Event 131 of root histo_two:
# **********************************************************************
#
# Event 132 of root histo_two:
# **********************************************************************
#
# Event 133 of root histo_two:
# **********************************************************************
#
# Event 134 of root histo_two:
# **********************************************************************
#
# Event 135 of root histo_two:
# **********************************************************************
#
# Event 136 of root histo_two:
# **********************************************************************
#
# Event 137 of root histo_two:
# **********************************************************************
#
# Event 138 of root histo_two:
# **********************************************************************
#
# Event 139 of root histo_two:
# **********************************************************************
#
# Event 140 of root histo_two:
# **********************************************************************
#
# Event 141 of root histo_two:
# **********************************************************************
#
# Event 142 of root histo_two:
# **********************************************************************
#
# Event 143 of root histo_two:
# **********************************************************************
#
# Event 144 of root histo_two:
# **********************************************************************
#
# Event 145 of root histo_two:
# **********************************************************************
#
# Event 146 of root histo_two:
# **********************************************************************
#
# Event 147 of root histo_two:
# **********************************************************************
#
# Event 148 of root histo_two:
# **********************************************************************
#
# Event 149 of root histo_two:
# **********************************************************************
#
# Event 150 of root histo_two:
# **********************************************************************
#
# Event 151 of root histo_two:
# **********************************************************************
#
# Event 152 of root histo_two:
# **********************************************************************
#
# Event 153 of root histo_two:
# **********************************************************************
#
# Event 154 of root histo_two:
# **********************************************************************
#
# Event 155 of root histo_two:
# **********************************************************************
#
# Event 156 of root histo_two:
# **********************************************************************
#
# Event 157 of root histo_two:
# **********************************************************************
#
# Event 158 of root histo_two:
# **********************************************************************
#
# Event 159 of root histo_two:
# **********************************************************************
#
# Event 160 of root histo_two:
# **********************************************************************
#
# Event 161 of root histo_two:
# **********************************************************************
#
# Event 162 of root histo_two:
# **********************************************************************
#
# Event 163 of root histo_two:
# **********************************************************************
#
# Event 164 of root histo_two:
# **********************************************************************
#
# Event 165 of root histo_two:
# **********************************************************************
#
# Event 166 of root histo_two:
# **********************************************************************
#
# Event 167 of root histo_two:
# **********************************************************************
#
# Event 168 of root histo_two:
# **********************************************************************
#
# Event 169 of root histo_two:
# **********************************************************************
#
# Event 170 of root histo_two:
# **********************************************************************
#
# Event 171 of root histo_two:
# **********************************************************************
#
# Event 172 of root histo_two:
# **********************************************************************
#
# Event 173 of root histo_two:
# **********************************************************************
#
# Event 174 of root histo_two:
# **********************************************************************
#
# Event 175 of root histo_two:
# **********************************************************************
#
# Event 176 of root histo_two:
# **********************************************************************
#
# Event 177 of root histo_two:
# **********************************************************************
#
# Event 178 of root histo_two:
# **********************************************************************
#
# Event 179 of root histo_two:
# **********************************************************************
#
# Event 180 of root histo_two:
# **********************************************************************
#
# Event 181 of root histo_two:
# **********************************************************************
#
# Event 182 of root histo_two:
# **********************************************************************
#
# Event 183 of root histo_two:
# **********************************************************************
#
# Event 184 of root histo_two:
# **********************************************************************
#
# Event 185 of root histo_two:
# ...
# **********************************************************************
#
# Event 344 of root histo_two:
# **********************************************************************
#
# Event 345 of root histo_two:
# **********************************************************************
#
# Event 346 of root histo_two:
# **********************************************************************
#
# Event 347 of root histo_two:
# **********************************************************************
#
# Event 348 of root histo_two:
# **********************************************************************
#
# Event 349 of root histo_two:
# **********************************************************************
#
# Event 350 of root histo_two:
# **********************************************************************
#
# Event 351 of root histo_two:
# **********************************************************************
#
# Event 352 of root histo_two:
# **********************************************************************
#
# Event 353 of root histo_two:
# **********************************************************************
#
# Event 354 of root histo_two:
# **********************************************************************
#
# Event 355 of root histo_two:
# **********************************************************************
#
# Event 356 of root histo_two:
# **********************************************************************
#
# Event 357 of root histo_two:
# **********************************************************************
#
# Event 358 of root histo_two:
# **********************************************************************
#
# Event 359 of root histo_two:
# **********************************************************************
#
# Event 360 of root histo_two:
# **********************************************************************
#
# Event 361 of root histo_two:
# **********************************************************************
#
# Event 362 of root histo_two:
# **********************************************************************
#
# Event 363 of root histo_two:
# **********************************************************************
#
# Event 364 of root histo_two:
# **********************************************************************
#
# Event 365 of root histo_two:
# **********************************************************************
#
# Event 366 of root histo_two:
# **********************************************************************
#
# Event 367 of root histo_two:
# **********************************************************************
#
# Event 368 of root histo_two:
# **********************************************************************
#
# Event 369 of root histo_two:
# **********************************************************************
#
# Event 370 of root histo_two:
# **********************************************************************
#
# Event 371 of root histo_two:
# **********************************************************************
#
# Event 372 of root histo_two:
# **********************************************************************
#
# Event 373 of root histo_two:
# **********************************************************************
#
# Event 374 of root histo_two:
# **********************************************************************
#
# Event 375 of root histo_two:
# **********************************************************************
#
# Event 376 of root histo_two:
# **********************************************************************
#
# Event 377 of root histo_two:
# **********************************************************************
#
# Event 378 of root histo_two:
# **********************************************************************
#
# Event 379 of root histo_two:
# **********************************************************************
#
# Event 380 of root histo_two:
# **********************************************************************
#
# Event 381 of root histo_two:
# **********************************************************************
#
# Event 382 of root histo_two:
# **********************************************************************
#
# Event 383 of root histo_two:
# **********************************************************************
#
# Event 384 of root histo_two:
# **********************************************************************
#
# Event 385 of root histo_two:
# **********************************************************************
#
# Event 386 of root histo_two:
# **********************************************************************
#
# Event 387 of root histo_two:
# **********************************************************************
#
# Event 388 of root histo_two:
# **********************************************************************
#
# Event 389 of root histo_two:
# **********************************************************************
#
# Event 390 of root histo_two:
# **********************************************************************
#
# Event 391 of root histo_two:
# **********************************************************************
#
# Event 392 of root histo_two:
# **********************************************************************
#
# Event 393 of root histo_two:
# **********************************************************************
#
# Event 394 of root histo_two:
# **********************************************************************
#
# Event 395 of root histo_two:
# **********************************************************************
#
# Event 396 of root histo_two:
# **********************************************************************
#
# Event 397 of root histo_two:
# **********************************************************************
#
# Event 398 of root histo_two:
# **********************************************************************
#
# Event 399 of root histo_two:
# **********************************************************************
#
# Event 400 of root histo_two:
# **********************************************************************
#
# Event 401 of root histo_two:
# **********************************************************************
#
# Event 402 of root histo_two:
# **********************************************************************
#
# Event 403 of root histo_two:
# **********************************************************************
#
# Event 404 of root histo_two:
# **********************************************************************
#
# Event 405 of root histo_two:
# **********************************************************************
#
# Event 406 of root histo_two:
# **********************************************************************
#
# Event 407 of root histo_two:
# **********************************************************************
#
# Event 408 of root histo_two:
# **********************************************************************
#
# Event 409 of root histo_two:
# **********************************************************************
#
# Event 410 of root histo_two:
# **********************************************************************
#
# Event 411 of root histo_two:
# **********************************************************************
#
# Event 412 of root histo_two:
# **********************************************************************
#
# Event 413 of root histo_two:
# **********************************************************************
#
# Event 414 of root histo_two:
# **********************************************************************
#
# Event 415 of root histo_two:
# **********************************************************************
#
# Event 416 of root histo_two:
# **********************************************************************
#
# Event 417 of root histo_two:
# **********************************************************************
#
# Event 418 of root histo_two:
# **********************************************************************
#
# Event 419 of root histo_two:
# **********************************************************************
#
# Event 420 of root histo_two:
# **********************************************************************
#
# Event 421 of root histo_two:
# **********************************************************************
#
# Event 422 of root histo_two:
# **********************************************************************
#
# Event 423 of root histo_two:
# **********************************************************************
#
# Event 424 of root histo_two:
# **********************************************************************
#
# Event 425 of root histo_two:
# **********************************************************************
#
# Event 426 of root histo_two:
# **********************************************************************
#
# Event 427 of root histo_two:
# **********************************************************************
#
# Event 428 of root histo_two:
# **********************************************************************
#
# Event 429 of root histo_two:
# **********************************************************************
#
# Event 430 of root histo_two:
# **********************************************************************
#
# Event 431 of root histo_two:
# **********************************************************************
#
# Event 432 of root histo_two:
# **********************************************************************
#
# Event 433 of root histo_two:
# **********************************************************************
#
# Event 434 of root histo_two:
# **********************************************************************
#
# Event 435 of root histo_two:
# **********************************************************************
#
# Event 436 of root histo_two:
# **********************************************************************
#
# Event 437 of root histo_two:
# **********************************************************************
#
# Event 438 of root histo_two:
# **********************************************************************
#
# Event 439 of root histo_two:
# **********************************************************************
#
# Event 440 of root histo_two:
# **********************************************************************
#
# Event 441 of root histo_two:
# **********************************************************************
#
# Event 442 of root histo_two:
# **********************************************************************
#
# Event 443 of root histo_two:
# **********************************************************************
#
# Event 444 of root histo_two:
# **********************************************************************
#
# Event 445 of root histo_two:
# **********************************************************************
#
# Event 446 of root histo_two:
# **********************************************************************
#
# Event 447 of root histo_two:
# **********************************************************************
#
# Event 448 of root histo_two:
# **********************************************************************
#
# Event 449 of root histo_two:
# **********************************************************************
#
# Event 450 of root histo_two:
# **********************************************************************
#
# Event 451 of root histo_two:
# **********************************************************************
#
# Event 452 of root histo_two:
# **********************************************************************
#
# Event 453 of root histo_two:
# **********************************************************************
#
# Event 454 of root histo_two:
# **********************************************************************
#
# Event 455 of root histo_two:
# **********************************************************************
#
# Event 456 of root histo_two:
# **********************************************************************
#
# Event 457 of root histo_two:
# **********************************************************************
#
# Event 458 of root histo_two:
# **********************************************************************
#
# Event 459 of root histo_two:
# **********************************************************************
#
# Event 460 of root histo_two:
# **********************************************************************
#
# Event 461 of root histo_two:
# **********************************************************************
#
# Event 462 of root histo_two:
# **********************************************************************
#
# Event 463 of root histo_two:
# **********************************************************************
#
# Event 464 of root histo_two:
# **********************************************************************
#
# Event 465 of root histo_two:
# **********************************************************************
#
# Event 466 of root histo_two:
# **********************************************************************
#
# Event 467 of root histo_two:
# **********************************************************************
#
# Event 468 of root histo_two:
# **********************************************************************
#
# Event 469 of root histo_two:
# **********************************************************************
#
# Event 470 of root histo_two:
# **********************************************************************
#
# Event 471 of root histo_two:
# **********************************************************************
#
# Event 472 of root histo_two:
# **********************************************************************
#
# Event 473 of root histo_two:
# **********************************************************************
#
# Event 474 of root histo_two:
# **********************************************************************
#
# Event 475 of root histo_two:
# **********************************************************************
#
# Event 476 of root histo_two:
# **********************************************************************
#
# Event 477 of root histo_two:
# **********************************************************************
#
# Event 478 of root histo_two:
# **********************************************************************
#
# Event 479 of root histo_two:
# **********************************************************************
#
# Event 480 of root histo_two:
# **********************************************************************
#
# Event 481 of root histo_two:
# **********************************************************************
#
# Event 482 of root histo_two:
# **********************************************************************
#
# Event 483 of root histo_two:
# **********************************************************************
#
# Event 484 of root histo_two:
# **********************************************************************
#
# Event 485 of root histo_two:
# **********************************************************************
#
# Event 486 of root histo_two:
# **********************************************************************
#
# Event 487 of root histo_two:
# **********************************************************************
#
# Event 488 of root histo_two:
# **********************************************************************
#
# Event 489 of root histo_two:
# **********************************************************************
#
# Event 490 of root histo_two:
# **********************************************************************
#
# Event 491 of root histo_two:
# **********************************************************************
#
# Event 492 of root histo_two:
# **********************************************************************
#
# Event 493 of root histo_two:
# **********************************************************************
#
# Event 494 of root histo_two:
# **********************************************************************
#
# Event 495 of root histo_two:
# **********************************************************************
#
# Event 496 of root histo_two:
# **********************************************************************
#
# Event 497 of root histo_two:
# **********************************************************************
#
# Event 498 of root histo_two:
# **********************************************************************
#
# Event 499 of root histo_two:
#
# Finding the Optimum set of parameters with this scaling
# Best parameters per event saved to event_best_with_cost.csv
#
# Overall best parameters: {'dc': 0.7, 'rhoc': 4, 'dm': 2, 'merge rate': 0.0, 'efficiency': 1.0}
# Pipeline completed.
